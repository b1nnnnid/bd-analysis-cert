# %% [markdown]
# # 제1유형

# %% [markdown]
# 1-1) 제공된 데이터 drinks.csv는 대륙, 국가, 맥주 소비량 등의 정보를 포함한 자료이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. continent : 대륙명
# 2. country : 국가명
# 3. beer_servings : 국가별 1인당 연간 맥주 소비량
#
# [수행 순서]
# 1. 대륙별 평균 맥주 소비량을 계산하여, 가장 평균 소비량이 많은 대륙을 구한다.
# 2. 1에서 구한 대륙 내에서 맥주 소비량 기준으로 다섯 번째로 많은 국가를 구한다.
# 3. 2에서 도출한 국가의 맥주 소비량을 구한다.
#
# [문제]
# 1. 수행 순서 3)에서 구한 맥주 소비량을 입력하시오.
#  ☞ [제출 형식] 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_1_drinks.csv')

# 여기에 코드를 작성하시오.

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_1_drinks.csv')

# 1. 대륙별 평균 맥주 소비량 계산
continent_avg = df.groupby('continent')['beer_servings'].mean().sort_values(ascending=False)
top_continent = continent_avg.index[0]

# 2. 해당 대륙에서 맥주 소비량 기준으로 다섯 번째로 많은 국가 구하기
target_df = df[df['continent'] == top_continent].sort_values(by='beer_servings', ascending=False)
fifth_country = target_df.iloc[4]

# 3. 해당 국가의 맥주 소비량 출력
print("①", fifth_country['beer_servings'])
# Out:
# ① 313

# %% [markdown]
# 1-2) 제공된 데이터 tourism.csv는 실제 국가별 관광 목적 및 공무 목적 입국자 수에 대한 정보를 포함한 자료이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. country : 국가명
# 2. tourism : 관광 목적 입국자 수
# 3. official : 공무 목적 입국자 수
#
# [수행 순서]
# 1. '총 입국 인원' 과 '관광객 비율' 파생변수를 생성한다.
#  ※ 총 입국 인원 = 관광 입국 인원 + 공무 입국 인원
#  ※ 관광객 비율 = 관광 입국 인원 / 총 입국 인원
# 2. 관광객 비율이 두 번째로 높은 나라의 관광 입국 인원을 A라고 한다.
# 3. 총 입국 인원이 두 번째로 많은 나라의 공무 입국 인원을 B라고 한다.
#
# [문제]
# 1. 수행 순서 2)와 3)에서 구한 A, B의 값의 합(A+B)을 입력하시오.
#  ☞ [제출 형식] 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_2_tourism.csv')

# 여기에 코드를 작성하시오.

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_2_tourism.csv')

# 1. 총 입국 인원 및 관광객 비율 컬럼 생성
df['total'] = df['tourism'] + df['official']
df['ratio'] = df['tourism'] / df['total']

# 2. A: 관광객 비율 두 번째로 높은 나라의 관광 인원
A = df.sort_values(by='ratio', ascending=False).iloc[1]['tourism']

# 3. B: 총 입국 인원이 두 번째로 많은 나라의 공무 인원
B = df.sort_values(by='total', ascending=False).iloc[1]['official']

# 결과 출력
print("①", A + B)
# Out:
# ① 700586

# %% [markdown]
# 1-3) 제공된 데이터 analysis.csv는 A 화학 공장의 생산 공정 중 원재료에 포함된 탄소 농도(Co)에 따른 설비의 성능 지표(Nmch)를 나타낸 자료이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. Co : 원재료에 포함된 탄소 농도
# 2. Nmch : 설비 성능 지표
#
# [수행 순서]
# 1. Co 컬럼과 Nmch 컬럼에 대해 최대-최소 정규화(Min-Max Scaling) 를 수행한다.
# 2. 정규화된 Co 컬럼의 표본표준편차를 A, 정규화된 Nmch 컬럼의 표본표준편차를 B라고한다.
#
# [문제]
# 1. 수행 순서 2)에서 구한 A, B의 값의 차이(A-B)를 입력하시오.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_3_analysis.csv')

# 여기에 코드를 작성하시오.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/1_3_analysis.csv')

# 1. Min-Max 정규화
scaler = MinMaxScaler()
scaled = scaler.fit_transform(df[['Co', 'Nmch']])
df_scaled = pd.DataFrame(scaled, columns=['Co', 'Nmch'])

# 2. 표준편차 계산
A = df_scaled['Co'].std()
B = df_scaled['Nmch'].std()

# 결과 출력
print("①", round(A - B, 3))
# Out:
# ① -0.041

# %% [markdown]
# # 제2유형

# %% [markdown]
# 제공된 데이터(subway_train.csv)는 특정 도시 지하철역의 환경 및 시설 정보 담고 있다. 이를 바탕으로 하루 평균 방문 인원수(Passengers)를 예측하는 회귀 모델을 개발하고, 가장 우수한 모델을 평가 데이터(subway_test.csv)에 적용하여 예측 결과를 도출하시오. 예측 결과는 아래의 [제출 형식]을 준수하여, CSV 파일로 생성하는 코드를 제출하시오.
#  * 예측결과는 MAE(Mean Absolute Error) 평가지표에 따라 평가함
#
# [제공 데이터]
# 1. subway_train.csv : 학습용 데이터 (824건)
# 2. subway_test.csv : 평가용 데이터 (312건, Passengers 미제공)
#
# [데이터 컬럼]
# 1. StationID: 지하철역 고유 ID
# 2. Line: 노선 이름 (Line1 ~ Line5)
# 3. Temperature: 평균 기온
# 4. Rainfall_mm: 강수량(mm)
# 5. Is_Holiday: 공휴일 여부 (0: 평일, 1: 공휴일)
# 6. Nearby_Shops: 상업시설 개수
# 7. Transfer_Stations: 환승역 수 (0~3)
# 8. Bus_Connections: 연결된 버스 노선 수
# 9. Passengers: 하루 방문 승객 수
#
# [제출 형식]
# 1. 제출 파일명 : result.csv
# 2. 제출 컬럼명 : pred
# 3. 예측 결과 개수 : 312

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcmd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이버 경로(C: 등) 접근 불가

import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/2_1_subway_train.csv')
test = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/2_1_subway_test.csv')

# 답안 제출 참고
# 아래 코드는 예시이며 변수명 등 개인별로 변경하여 활용
# pd.DataFrame변수.to_csv('result.csv', index=False)

# 여기에 코드를 작성하시오.

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcmd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이버 경로(C: 등) 접근 불가

import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/2_1_subway_train.csv')
test = pd.read_csv('/content/drive/MyDrive/BigData/Exam/8/2_1_subway_test.csv')

# X, Y 데이터 셋 분리
X = train.drop(['Passengers'], axis=1)
y = train['Passengers']

X_full = pd.concat([X, test], axis=0)
X_full = X_full.drop(['StationID'], axis=1)
#print(X_full.shape)

# 범주형 변수 인코딩 - One-Hot Encoding
X_full = pd.get_dummies(X_full)
#print(X_full)

# 학습, 검증 데이터 셋 분할
X_train = X_full[:train.shape[0]]
X_test = X_full[train.shape[0]:]
#print(X_train.shape, X_test.shape)

from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y, test_size=0.2)
#print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)

# Randomforest 활용 모델 학습
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)

# RAE, R2 Score 활용 평가
from sklearn.metrics import mean_absolute_error, r2_score
y_pred = model.predict(X_val)
mae = mean_absolute_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
print(mae, r2)

# test 데이터 예측 및 결과 저장 (pred 1개 컬럼)
y_pred = model.predict(X_test)
result = pd.DataFrame(y_pred, columns=['pred'])
result.to_csv('result.csv', index=False)
# Out:
# 68.23951515151515 0.901521822734063

# %% [markdown]
# # 제3유형

# %% [markdown]
# 3-1) 제공된 데이터(churn.csv)는 통신 서비스 고객의 사용 특성과 이탈 여부를 포함하고 있으며, 아래 데이터를 이용하여 고객 이탈 여부를 예측하고자 한다. 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 답안 제출 페이지에 입력하시오.
#
# [제공 데이터]
# 1. AvgCallMinutes : 고객의 월 평균 통화 시간 (분)
# 2. ContractMonths :	계약 유지 개월 수
# 3. InternationalPlan : 국제전화 요금제 가입 여부
# 4. TechSupport : 기술지원 서비스 가입 여부
# 5. Calls : 월 평균 전화 건수
# 6. Churn : 고객 이탈 여부 (1: 이탈, 0: 유지)
#
# [문제]
# 1. 위 데이터로 로지스틱 회귀분석을 수행하였을 때, 유의수준 0.05 기준으로 유의하지 않은 독립변수의 개수를 구하여라.
#  ☞ [제출 형식] 정수(integer)로 작성
# 2. ①에서 유의하지 않은 독립변수들을 제거한 후 회귀모델을 재학습하고, 회귀계수들의 평균값(절편 제외)을 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 3. ②에서 구축한 모델을 활용하여, Calls 값이 5 증가할 때 오즈비가 몇 배 증가하는지를 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/BigData/Exam/8/3_1_churn.csv")

# 여기에 코드를 작성하시오.

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/BigData/Exam/8/3_1_churn.csv")

import statsmodels.formula.api as smf
import numpy as np

# ① 모든 변수 포함한 로지스틱 회귀모형 적합
model_full = smf.logit('Churn ~ AvgCallMinutes + ContractMonths + InternationalPlan + TechSupport + Calls', data=df).fit()
print(model_full.summary())

pvals = model_full.pvalues.drop("Intercept")
sig_vars = list(pvals[pvals > 0.05].index)
not_significant_count = len(sig_vars)
print("① 유의하지 않은 변수 개수:", not_significant_count)

# ② 유의하지 않은 독립변수 제거 후 모형 재학습
model_sig = smf.logit('Churn ~ InternationalPlan + TechSupport + Calls', data=df).fit()
coef_mean = round(model_sig.params.drop("Intercept").mean(), 3)
print("② 회귀계수 평균 값:", coef_mean)

# ③ Calls값 5증가 할때 오즈
calls_coef = model_sig.params['Calls']
odds_ratio_5 = round(np.exp(calls_coef * 5), 3)
print("③ Calls 오즈비:", odds_ratio_5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.570255
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      394
# Method:                           MLE   Df Model:                            5
# Date:                Fri, 24 Oct 2025   Pseudo R-squ.:                 0.08184
# Time:                        04:54:29   Log-Likelihood:                -228.10
# converged:                       True   LL-Null:                       -248.43
# Covariance Type:            nonrobust   LLR p-value:                 1.096e-07
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -1.8591      0.614     -3.028      0.002      -3.063      -0.656
# ...

# %% [markdown]
# 3-2) 제공된 데이터(piq.csv)는 개인의 지능지수(PIQ)와 신체 및 두뇌 관련 정보를 포함하고 있으며, 아래 데이터를 이용하여 지능지수를 예측하고자 한다. 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 답안 제출 페이지에 입력하시오. (단, 모델은 절편을 포함한다.)
#
# [제공 데이터]
# 1. PIQ: 지능지수
# 2. BRAIN: 뇌 용적 (cm³)
# 3. HEIGHT: 신장 (inch)
# 4. WEIGHT: 체중 (pound)
#
# [문제]
# 1. BRAIN, HEIGHT, WEIGHT를 독립변수로 사용하여 다중선형회귀분석을 수행하고, 이때 p-value가 가장 작은 독립변수의 회귀계수 값을 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 2. ①에서 구축한 모델의 결정계수(R-Sqaured) 값을 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 3. ①에서 구축한 모델을 이용하여, 아래 새로운 데이터 정보를 입력했을 때 예상 PIQ를 구하여라.
# (BRAIN=100, HEIGHT=72, WEIGHT=128)
#   ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/BigData/Exam/8/3_2_piq.csv")

# 여기에 코드를 작성하시오.

# %%
import pandas as pd
import statsmodels.formula.api as smf

df = pd.read_csv("/content/drive/MyDrive/BigData/Exam/8/3_2_piq.csv")

# 선형 회귀 모델 학습
model = smf.ols("PIQ ~ BRAIN + HEIGHT + WEIGHT", data=df).fit()
print(model.summary())

# 1. 가장 작은 p-value 변수의 회귀계수
pvalues = model.pvalues.drop("Intercept")
min_pval_var = pvalues.idxmin()
min_pval_coef = model.params[min_pval_var]
print("1. 가장 작은 p-value 변수의 회귀계수:", round(min_pval_coef, 3))

# 2. 결정계수 (R-squared)
r_squared = model.rsquared
print("2. R-squared:", round(r_squared, 3))

# 3. 예측값 계산
new_data = pd.DataFrame({"BRAIN": [100], "HEIGHT": [72], "WEIGHT": [128]})
pred = model.predict(new_data)
print("3. 예측된 PIQ:", round(pred[0], 3))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    PIQ   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     30.89
# Date:                Fri, 24 Oct 2025   Prob (F-statistic):           1.60e-15
# Time:                        04:54:30   Log-Likelihood:                -518.68
# No. Observations:                 150   AIC:                             1045.
# Df Residuals:                     146   BIC:                             1057.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.1618     16.623      2.536      0.012       9.309      75.014
# ...
