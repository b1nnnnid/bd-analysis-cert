# %% [markdown]
# # 제1유형

# %% [markdown]
# 1-1) 제공된 데이터 loan.csv는 연도, 성별, 지역코드, 대출금액을 포함한 자료이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. 년도 : 대출이 발생한 년도
# 2. 성별 : 대출자 성별 구분 (0: 남성, 1: 여성)
# 3. 지역코드 : 지역 식별 코드값
# 4. 신용대출 : 신용 기반 대출 금액 (단위 : 원)
# 5. 담보대출 : 담보 제공 대출 금액 (단위 : 원)
#
# [수행 순서]
# 1. 총대출액을 신용대출과 담보대출의 합으로 계산한다.
# 2. 각 연도별로 성별 간 총대출액의 절댓값 차이를 계산한다.
# 3. 총 대출액의 절댓값 차이가 가장 큰 연도의 지역코드를 구한다. 이때, 해당 연도의 전체 데이터에서 가장 많이 등장한 지역코드를 구한다.
#
# [문제]
# 1. 수행 순서 3)에서 계산한 지역코드를 입력하시오.
#  ☞ [제출 형식] 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv("../data/9/1_1_loan.csv")

# 여기에 코드를 작성하시오.
# print(df.head(10))

df['총대출액'] = df['신용대출'] + df['담보대출']
sum_loan = df.groupby(['년도', '성별'])['총대출액'].sum() # 리스트로 그룹바이 가능
# print(sum_loan)

unstacked = sum_loan.unstack(level='성별') # 성별 값들을 칼럼으로 승격
# print(unstacked)
diff = (unstacked[0]-unstacked[1]).abs()
# print(diff)

max_code = df['지역코드'][df['년도']==diff.idxmax()].value_counts().idxmax()

print("ans: ", max_code)
# Out:
# ans:  24000000

# %% [markdown]
# 1-2) 제공된 데이터 crime.csv는 각 연도별로 발생한 범죄 유형별 검거건수와 발생 건수 정보를 포함하고 있다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. 연도 : 범죄 통계 연도
# 2. 구분 : '검거건수' 또는 '발생건수'
# 3. 범죄유형1 ~ 범죄유형N : 각 범죄 유형별 건수
#
# [수행 순서]
# 1. 각 연도별로 범죄 유형별 검거율을 계산한다.
#  ※ 검거율 = 검거건수 / 발생건수
# 2. 각 연도에서 검거율이 가장 높은 범죄 유형을 하나씩 식별한다.
# 3. 2에서 식별한 범죄 유형의 검거건수만 연도별로 모아 모두 합산한다.
#  ※ 예: 2015년의 최고 검거율이 절도였다면, 2015년 절도의 '검거건수'만 수집
#
# [문제]
# 1. 수행 순서 3)에서 계산한 검거건수 총합을 입력하시오.
#  ☞ [제출 형식] 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv("../data/9/1_2_crime.csv")

# 여기에 코드를 작성하시오.

df_occurred = df[df['구분']=='발생건수'].set_index('연도').drop('구분',axis=1)
df_detected = df[df['구분']=='검거건수'].set_index('연도').drop('구분',axis=1) #두 테이블로 쪼개기

# print(df_occurred, df_detected)

type_ratio = df_detected/df_occurred # 테이블끼리 나누기 연산 가능
# print(type_ratio)
highest_types = type_ratio.idxmax(axis=1) #idxmax에 axis 옵션 가능
# print(highest_types)

total_detect = sum(df_detected.loc[year, crimetype] for year, crimetype in highest_types.items()) # 컴프리헨션 or for 문 활용하기(노가다도 가능)
print("ans: ", total_detect)
# Out:
# ans:  4096

# %% [markdown]
# 1-3) 제공된 데이터 hr.csv는 각 직원의 부서, 성과등급, 근속연수, 만족도, 교육참가횟수 정보를 담고 있다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. 부서 : 직원이 속한 부서명
# 2. 성과등급 : 직원 성과 수준 (A, B, C)
# 3. 근속연수 : 직원의 근무 연수
# 4. 만족도 : 1~10 사이의 만족도 점수
# 5. 교육참가횟수 : 연간 사내 교육 참여 횟수
#
# [수행 순서]
# 1. 만족도의 결측치는 전체 평균값으로 대체한다.
# 2. 근속연수의 결측치는 동일한 부서 내에서 같은 성과등급을 가진 직원들의 평균 근속연수로 대체한다. 이때, 소수점 이하는 버리고 정수로 대체한다.
# 3. 부서 평균 만족도가 가장 높은 부서를 찾고, 해당 부서 내 성과등급별 평균 만족도를 계산한다. 이 중 가장 낮은 성과등급의 평균 근속연수를 A라고 한다.
# 4. 각 지원의 ‘연봉만족도 = 근속연수 / 만족도’ 값을 계산하고, 이 값이
# 두 번째로 큰 직원의 교육참가횟수를 B라고 한다.
#
# [문제]
# 1. 수행 순서 3)과 4)에서 구한 A, B의 값의 합(A+B)을 입력하시오.
#  ☞ [제출 형식] 버림하여 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv("../data/9/1_3_hr.csv")

# 여기에 코드를 작성하시오.

# print(df.head(10))
df['만족도'] = df['만족도'].fillna(df['만족도'].mean())
# print(df['만족도'].isnull().sum())

processed_year = df.groupby(['성과등급', '부서'])['근속연수'].transform("mean").astype(int) #그냥 mean이 안되면 transform 해보기
# print(processed_year)
df['근속연수'] = df['근속연수'].fillna(processed_year)
# print(df['근속연수'].isnull().sum())

department = df.groupby('부서')['만족도'].mean().idxmax()
# print(department)
satisfaction = df[df['부서']==department].groupby('성과등급')['만족도'].mean()
# print(satisfaction)
low_grade = satisfaction.idxmin()
A = df[(df['성과등급']==low_grade) & (df['부서']==department)]['근속연수'].mean()

df['연봉만족도'] = df['근속연수']/df['만족도']
# print(df['연봉만족도'].sort_values(ascending=False))
B = df.iloc[48]['교육참가횟수']

print("ans: ", int(A+B))
# Out:
# ans:  18

# %% [markdown]
# # 제2유형

# %% [markdown]
# 제공된 데이터(pesticide_train.csv)는 작물 시료의 환경·재배 정보를 담고 있다. 이를 바탕으로 농약 검출 여부(Pesticide_Result)를 예측하는 분류 모델을 개발하고, 가장 우수한 모델을 평가 데이터(pesticide_test.csv)에 적용하여 예측 결과를 도출하시오. 예측 결과는 아래의 [제출 형식]을 준수하여, CSV 파일로 생성하는 코드를 제출하시오.
#  * 예측결과는 Macro F1 Score 평가지표에 따라 평가함
#
# [제공 데이터]
# 1. pesticide_train.csv : 학습용 데이터 (2,400건)
# 2. pesticide_test.csv : 평가용 데이터 (600건, Pesticide_Result 미제공)
#
# [데이터 컬럼]
# 1. Crop: 작목 (배추/상추/토마토/고추/사과/포도/감귤)
# 2. Season: 계절 (봄/여름/가을/겨울)
# 3. Farm_Method: 재배 방식 (관행/유기)
# 4. Greenhouse: 시설 여부 (Y/N)
# 5. Area_ha: 재배 면적(ha)
# 6. Days_Since_Spray: 마지막 살포 후 경과일수
#   …
# 7. Pesticide_Result: 농약 검출 여부(0: 미검출, 1: 검출, 2: 확인불가)
#
# [제출 형식]
# 1. 제출 파일명 : result.csv
# 2. 제출 컬럼명 : pred
# 3. 예측 결과 개수 : 600

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcmd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이버 경로(C: 등) 접근 불가

import pandas as pd

train = pd.read_csv('../data/9/2_1_pesticide_train.csv')
test = pd.read_csv('../data/9/2_1_pesticide_test.csv')

# 답안 제출 참고
# 아래 코드는 예시이며 변수명 등 개인별로 변경하여 활용
# pd.DataFrame변수.to_csv('result.csv', index=False)

# 여기에 코드를 작성하시오.
# print(train.info())
# print(test.info())

# print(train.isnull().sum())
# print(test.isnull().sum())

X = train.drop('Pesticide_Result', axis=1)
y = train['Pesticide_Result']

X_full = pd.concat([X, test], axis=0)
# print(X_full.shape)

X_full = pd.get_dummies(X_full)
# print(X_full)

X_train = X_full[:train.shape[0]]
test = X_full[train.shape[0]:]

from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y, test_size=0.2, stratify=y, random_state=0)
# print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)

# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier()
# model.fit(X_train, y_train)

from xgboost import XGBClassifier
model = XGBClassifier(n_estimators=300, max_depth=6)
model.fit(X_train, y_train)

# from lightgbm import LGBMClassifier
# model = LGBMClassifier()
# model.fit(X_train, y_train)

from sklearn.metrics import f1_score, accuracy_score
y_pred = model.predict(X_val)
f1 = f1_score(y_val, y_pred, average='macro')
acc = accuracy_score(y_val, y_pred)
print(f1, acc)

y_pred = model.predict(test)
result = pd.DataFrame(y_pred, columns=['pred'])
print(result)
result.to_csv('result_9.csv', index=False)
# Out:
# 0.7931149971877077 0.9645833333333333
#      pred
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 595     0
# 596     0
# 597     0
# 598     0
# 599     0
#
# [600 rows x 1 columns]

# %% [markdown]
# # 제3유형

# %% [markdown]
# 3-1) 제공된 데이터 design.csv는 디자인 점수와 관련한 다섯 개의 설명변수를 포함한 자료이다. 아래 데이터를 이용하여 디자인 점수를 예측하고자 한다. 전체 200개 중 앞의 140개는 학습용(train), 뒤의 60개는 시험용(test) 데이터로 사용한다. 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 답안 제출 페이지에 입력하시오. (단, 모델은 절편을 포함한다.)
#
# [제공 데이터]
# 1. f1, f2, f3, f4, f5 : 연속형 설명변수
# 2. design : 디자인 점수
#
# [문제]
# 1. f1, f2, f3, f4, f5를 독립변수로 하여 학습용(train) 데이터를 이용해 다중선형회귀분석을 수행하고, 절편을 제외한 독립변수 중 p값이 0.05보다 작은 변수의 개수를 구하여라.
#  ☞ [제출 형식] 정수(integer)로 작성
# 2. ①의 결과를 바탕으로 유의수준 0.05 기준에서 유의하지 않은 독립변수를 제거한 후, 남은 변수만을 이용하여 다시 다중선형회귀분석을 수행한다. 이 모델로 train 데이터의 design 예측값을 산출한 뒤, 예측값과 실제 design값 사이의 피어슨 상관계수를 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 3. ②에서 구축한 모형을 시험용(test) 데이터에 적용하여 예측값을 구하고, RMSE를 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd

df = pd.read_csv("../data/9/3_1_design.csv")

# 여기에 코드를 작성하시오.
# print(df.head(10))

train = df.iloc[:140]
test = df.iloc[140:]

import statsmodels.formula.api as smf

model = smf.ols('design ~ f1 + f2 + f3 + f4 + f5', data=train).fit()
# print(model.summary())

ans1 =2
print("ans1: ", ans1)

model2 = smf.ols('design ~ f2 + f4',data=train).fit()
# print(model2.summary())
train['pred'] = model2.predict(train) #칼럼으로 만들어주기
# print(train['pred'])

ans2 = round(train[['design','pred']].corr().iloc[0][1],3) #피어슨은 그냥 corr, 인덱스 지정 시에 iloc 빼먹지 말기
print("ans2: ", ans2)

from sklearn.metrics import root_mean_squared_error
pred = model2.predict(test)
rmse = root_mean_squared_error(test['design'], pred) #실제 값과 예측값으로 비교
ans3 = round(rmse,3)
print("ans3: ", ans3)
# Out:
# ans1:  2
# ans2:  0.988
# ans3:  0.993
# C:\Users\YSB\AppData\Local\Temp\ipykernel_24844\3720984405.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['pred'] = model2.predict(train)
# C:\Users\YSB\AppData\Local\Temp\ipykernel_24844\3720984405.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ans2 = round(train[['design','pred']].corr().iloc[0][1],3)

# %% [markdown]
# 3-2) 제공된 데이터 retention.csv는 통신 서비스 고객의 요금/이용 특성과 이탈 여부를 포함하고 있다. 아래 데이터를 이용하여 이탈 확률을 예측하고자 한다. 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 답안 제출 페이지에 입력하시오.
#
# [제공 데이터]
# 1. MonthlyFee : 고객의 월 납부 요금
# 2. ServiceMonths : 서비스 이용 개월 수
# 3. PhonePlan : 전화 서비스 이용 여부 (1: 이용, 0: 미이용)
# 4. DeviceProtect : 기기보호 서비스 가입 여부 (1: 가입, 0: 미가입)
# 5. Leave: 고객 이탈 여부 (1: 이탈, 0: 유지)
#
# [문제]
# 1. MonthlyFee, ServiceMonths, PhonePlan, DeviceProtect을 독립변수로 사용하여 로지스틱회귀분석을 수행하고, ServiceMonths 변수의 p값을 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 2. ①번에서 만든 모델을 이용하여, 전화 서비스를 받지 않은 고객 대비 전화 서비스를 받은 고객의 이탈할 오즈비를 구하여라.
#  ☞ [제출 형식] 반올림하여 소수 셋째 자리까지 작성
# 3. ①번에서 만든 모델로 각 고객의 이탈 확률을 예측한 후, 예측 확률이 0.3을 초과하는 고객 수를 구하여라.
#  ☞ [제출 형식] 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv("../data/9/3_2_retention.csv")

# 여기에 코드를 작성하시오.

import statsmodels.formula.api as smf
model = smf.logit('Leave ~ MonthlyFee + ServiceMonths + PhonePlan + DeviceProtect', data=df).fit()
# print(model.summary())
ans1 = 0.011
print("ans1: ", ans1)

import numpy as np
odds_ratio = float(np.exp(model.params['PhonePlan']))
ans2 = round(odds_ratio,3)
print("ans2: ", ans2)

pred = model.predict(df)
ans3 = len(pred[pred>0.3])
print("ans3: ", ans3)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.203842
#          Iterations 8
# ans1:  0.011
# ans2:  0.449
# ans3:  12
