# %% [markdown]
# # Ch12. (2유형) 회귀

# %%
# 랜덤포레스트(추천): 여러 개의 의사결정트리를 랜덤하게 학습시켜 앙상블
# 과적합 방지, 안정적 예측, 일반화 성능 확보에 유리

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y)

# %%
# XGBoost: 여러 결정 트리를 순차적 학습시켜 성능을 개선하는 부스팅 모델
# 성능 뛰어나고 과적합 제어 가능
# 과적합 위험: 하이퍼파라미터 튜닝 필요

from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train, y)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. MAE: 예측값/실제값 차이의 절댓값 평균(작을수록 좋다)
mae = mean_absolute_error(y_true, y_pred)

# 2. MSE: 예측값/실제값 차이의 제곱 평균(이상치 민감, 작을수록 좋다)
mse = mean_squared_error(y_true, y_pred)

# 3. R2 Score(모델이 데이터를 얼마나 잘 설명하는지, 1에 가까울수록 좋다)
r2 = r2_score(y_true, y_pred)
