# %% [markdown]
# # 심화강의. (2유형) 모델의 튜닝 및 최적화

# %% [markdown]
# ## 여러 모델의 활용

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
# 여러 의사결정트리를 랜덤하게 학습시켜 앙상블...운이 작용
model = RandomForestClassifier()
model.fit(X_train, y_train)

# %%
from xgboost import XGBRegressor, XGBClassifier
# 여러 약한 결정트리 모델을 순차 학습하는 부스팅 모델델
model = XGBClassifier()
model.fit(X_train, y_train)

# %%
from lightgbm import LGBMRegressor, LGBMClassifier
# Gradient 부스팅 기반
model = LGBMClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# ## 하이퍼파라미터 튜닝

# %%
# 시험에서 튜닝해볼만한 파라미터
# n_estimators: 트리 개수, 성능에 영향 큼(너무 올리면 시간 초과 가능성)... 추천값: 100, 300, 500
# max_depth: 트리 최대 깊이, 과적합 조절(깊을수록 과적합 가능성)... 추천값: 4, 6, 8

# 그 외 활용가능한 파라미터(부스팅 계열)
# learning_rate: 학습률(추천값 0.01~0.2)
# subsample: 데이터 샘플링 비율(추천값 0.6~1.0)


RandomForestClassifier(n_estimators=300, max_depth=6)
XGBClassifier(n_estimators=300, max_depth=6)
LGBMClassifier(n_estimators=300, max_depth=6)
