# %% [markdown]
# # Ch13. (2유형) 이진분류

# %%
from sklearn.model_selection import train_test_split

# staritify=y: 훈련/검증 데이터에서 클래스 비유을 동일하게 유지... 층화추출
# 분류 문제에 클래스 불균형 있을 때 필수 -> 생존/사망, 정상/이상 여부 등
X_train, X_val, y_train, y_val = train_test_split(X_train, y
                                                  , test_size=0.2, stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier
# 과적합 방지, 안정적 예측, 일반화 성능 확보에 유리
model = RandomForestClassifier()
model.fit(X_train, y_train)

# %%
from xgboost import XGBClassifier
# 성능 뛰어나고 과적합 제어 가능하나 하이퍼파라미터 튜닝 필요
model = XGBClassifier()
model.fit(X_train, y_train)

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# 예측값
y_pred = model.predict(X_val) # 보통 0 or 1 튀어나옴
y_proba = model.predict_proba(X_val)[:, 1]  # 양성 클래스 확률, 0~1 사잇값이 튀어나옴

# 지표 계산
roc_auc = roc_auc_score(y_true, y_proba) # ROC 커브 아래 면적(1에 가까울수록 좋음, 0.5 랜덤)
acc = accuracy_score(y_true, y_pred) # 전체 예측 중 정답 비율
prec = precision_score(y_true, y_pred) # 양성 예측 중 실제 양성 비율
rec = recall_score(y_true, y_pred) # 실제 양성 중 모델이 맞춘 비율
f1 = f1_score(y_true, y_pred) # 정밀도, 재현율의 조화 평균(1에 가까울수록 좋음음)
