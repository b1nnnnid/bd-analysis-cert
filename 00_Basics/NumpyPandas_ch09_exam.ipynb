# %% [markdown]
# #1. 다음 두 DataFrame을 concat하여 행 방향으로 병합하고, 인덱스를 다시 설정하려면 어떤 코드를 써야 할까?

# %%
import pandas as pd

df1 = pd.DataFrame({'이름': ['영희'], '점수': [95]})
df2 = pd.DataFrame({'이름': ['민수'], '점수': [88]})

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#    이름  점수
# 0  영희  95
# 1  민수  88
