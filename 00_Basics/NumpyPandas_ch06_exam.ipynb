# %% [markdown]
# #Ch06 연습문제

# %% [markdown]
# # 1.다음 코드를 실행했을 때 출력 결과를 예측하시오.

# %%
import pandas as pd
data = {
    '이름': ['영희', '철수'],
    '나이': [20, 22],
    '성별': ['여', '남'],
    '점수': [95, 90]
}
df = pd.DataFrame(data)
df.set_index('이름', inplace=True)
print(df.iloc[0, 1:2])
print(df.iloc[0, 1:])
# Out:
# 성별    여
# Name: 영희, dtype: object
# 성별     여
# 점수    95
# Name: 영희, dtype: object

# %% [markdown]
# # 2. 다음 코드는 정상적으로 실행되는 코드인가? 정상적이라면 결과를 예측하고, 오류가 발생한다면 이유를 설명하시오.

# %%
import pandas as pd
df = pd.read_csv('coin.csv', index_col='Date')
# print(df['Open','Close']) 여러개 선택할 때는 반드시 리스트로 전달
print(df[['Open','Close']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\YSB\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Open', 'Close')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ...

# %% [markdown]
# # 여러 열을 선택할 경우, 반드시 열 이름을 리스트로 전달해야 한다. 따라서 다음과 같이 작성해야 정상동작 한다.

# %%
print(df[['Open','Close']])
# Out:
#               Open   Close
# Date
# 2017-03-01  25,534  26,382
# 2017-03-02  24,941  25,439
# 2017-03-03  25,860  24,941
# 2017-03-04  25,886  25,860
# 2017-03-05  26,135  25,886
# ...            ...     ...
# 2018-02-25  20,501  20,444
# 2018-02-26  17,727  20,501
# 2018-02-27  20,618  17,727
# 2018-02-28  20,683  20,627
# 2018-03-01  21,693  20,683
#
# [366 rows x 2 columns]
