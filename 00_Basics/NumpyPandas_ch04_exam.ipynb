# %% [markdown]
# # Ch04 연습문제

# %% [markdown]
# #1. 다음 코드를 실행하였을 때 출력 결과를 예측하시오.

# %%
import pandas as pd
df = pd.read_csv('countries.csv')
print(df.head(3))
# Out:
#   Unnamed: 0 country     area     capital  population
# 0         KR   Korea    98480       Seoul    51780579
# 1         US     USA  9629091  Washington   331002825
# 2         JP   Japan   377835       Tokyo   125960000

# %% [markdown]
# #2. 다음 코드를 실행하였을 때 출력 결과를 예측하시오.

# %%
import pandas as pd
df = pd.read_csv('weather.csv')
print(df[2:5])
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustSpeed
# 2     13.7     23.4       3.6           85.0
# 3     13.3     15.5      39.8           54.0
# 4      7.6     16.1       2.8           50.0

# %% [markdown]
# # 3.다음 코드를 실행했을 때, pandas의 std()와 numpy의 std() 결과가 다른 이유를 간단히 설명하시오.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Data/countries.csv')
print(df['population'].std())
print(np.std(df['population']))

# 판다스의 표준편차: 기본으로 n-1로 나눔(표본 표준편차)
# 넘파이의 표준편차: 기본으로 n으로 나눔(모집단 표준편차)
# Out:
# 536207925.7389614
# 489488627.40047354
