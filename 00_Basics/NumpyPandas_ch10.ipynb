# %% [markdown]
# # Ch10. 파일처리

# %%
# read_csv 의 주요 옵션들

# index_col: 특정 열을 인덱스로 지정
# encoding: 인코딩 형식 지정(예: utf-8, cp949)
# usecols: 불러올 열만 지정 가능
# nrows: 불러올 행의 수 지정

import pandas as pd
df = pd.read_csv('coin.csv', index_col='Date')
df
# Out:
#               Open    High     Low   Close
# Date
# 2017-03-01  25,534  26,446  25,222  26,382
# 2017-03-02  24,941  25,471  24,801  25,439
# 2017-03-03  25,860  26,044  24,900  24,941
# 2017-03-04  25,886  26,343  25,742  25,860
# 2017-03-05  26,135  26,151  25,677  25,886
# ...            ...     ...     ...     ...
# 2018-02-25  20,501  20,940  19,840  20,444
# 2018-02-26  17,727  20,635  17,727  20,501
# 2018-02-27  20,618  20,723  17,630  17,727
# 2018-02-28  20,683  21,268  20,219  20,627
# 2018-03-01  21,693  22,899  20,522  20,683
#
# [366 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv('coin.csv', index_col='Date')
print(df.head())

# to_csv 주요 옵션들

# index=True(기본): 인덱스 정보 포함
# index-False: 인덱스 정보 제외
# encoding

df.to_csv('coin_saved.csv', index=True)           # 인덱스 포함 저장
df.to_csv('coin_saved_noindex.csv', index=False)  # 인덱스 제외 저장
# Out:
#               Open    High     Low   Close
# Date
# 2017-03-01  25,534  26,446  25,222  26,382
# 2017-03-02  24,941  25,471  24,801  25,439
# 2017-03-03  25,860  26,044  24,900  24,941
# 2017-03-04  25,886  26,343  25,742  25,860
# 2017-03-05  26,135  26,151  25,677  25,886
