# %% [markdown]
# #Ch05 연습문제

# %% [markdown]
# # 1.다음 코드를 실행했을 때 출력 결과를 예측하시오.

# %%
import pandas as pd
df = pd.DataFrame({'name': ['Tom', 'Jane'], 'age': [20, 22]})
df['gender'] = 'M'
print(df)
# Out:
#    name  age gender
# 0   Tom   20      M
# 1  Jane   22      M

# %% [markdown]
# # 2.다음 코드를 실행했을 때 출력 결과를 예측하시오

# %%
df = pd.DataFrame({'name': ['Tom', 'Jane'], 'age': [20, 22], 'gender' : ['M', 'M']})
df.loc[2] = ['Minho', 23, 'M']
print(df)
# Out:
#     name  age gender
# 0    Tom   20      M
# 1   Jane   22      M
# 2  Minho   23      M

# %% [markdown]
# # 3.다음 코드를 실행했을 때 출력 결과를 예측하시오

# %%
df = pd.read_csv('countries.csv')

#0번은 이미 존재하는 인덱스: 기존 0번 행의 값을 덮어씀(새로 추가x)
df.loc[0] = ['KR', 'NewCountry', 10000, 'Newcity', 10000000]
print(df)
# Out:
#   Unnamed: 0     country      area     capital  population
# 0         KR  NewCountry     10000     Newcity    10000000
# 1         US         USA   9629091  Washington   331002825
# 2         JP       Japan    377835       Tokyo   125960000
# 3         CN       China   9596960     Beijing  1439323688
# 4         RU      Russia  17100000      Moscow   146748600
# 5         DE     Germany    357022      Berlin    83200000
